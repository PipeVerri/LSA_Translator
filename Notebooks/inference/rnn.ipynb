# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Cargar el dataset
from utils.lsa64.dataset import LSA64Dataset
from torch.utils.data import DataLoader, random_split
import torch

dataset = LSA64Dataset("../../data/LSA64/landmarks")
torch.manual_seed(42)

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train_ds, test_ds = random_split(dataset, [train_size, test_size])

# %%
from torch.nn.utils.rnn import pad_sequence
# Cargarlo al GPU, random_split ya lo shufflea, padearlo con 0s asi tienen el mismo tamaño(al entrenar se ignoran esos 0s)
def collate_pad(batch):
    xs, ys = zip(*batch)
    lengths = torch.tensor([x.size(0) for x in xs])
    x_padded = pad_sequence(xs, batch_first=True, padding_value=0.0)
    y_tensor = torch.tensor(ys)
    return x_padded, lengths, y_tensor

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True, num_workers=6, collate_fn=collate_pad) # Shufflearlo por cada epoch
test_loader = DataLoader(test_ds, batch_size=32, num_workers=6, collate_fn=collate_pad)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
print(print(len(train_ds), len(test_ds)))
# Out:
# 2552 639
# None

# %%
from models import SimpleRNN

# %%
import torch.nn as nn

EPOCH = 200

model = SimpleRNN().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-3)
criterion = nn.CrossEntropyLoss()

# ==========================================
# TRACK BEST PERFORMANCES
# ==========================================
best_train_acc = 0
best_train_acc_test_acc = 0

best_test_acc = 0
best_test_acc_train_acc = 0
# ==========================================

for epoch in range(EPOCH):
    # ======================
    # TRAIN
    # ======================
    model.train()
    for x, lengths, y in train_loader:
        x = x.to(device)
        y = y.to(device)

        y_pred = model(x, lengths)
        loss = criterion(y_pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # ======================
    # TRAIN ERROR (subset)
    # ======================
    model.eval()
    train_loss = 0
    train_correct = 0
    train_total = 0
    train_batches = 5

    with torch.no_grad():
        for i, (x, lengths, y) in enumerate(train_loader):
            if i >= train_batches:
                break

            x = x.to(device)
            y = y.to(device)

            y_pred = model(x, lengths)
            loss = criterion(y_pred, y)
            train_loss += loss.item()

            _, predicted = y_pred.max(1)
            train_correct += (predicted == y).sum().item()
            train_total += y.size(0)

    avg_train_loss = train_loss / train_batches
    train_acc = 100 * train_correct / train_total

    # ======================
    # TEST ERROR
    # ======================
    test_loss = 0
    test_correct = 0
    test_total = 0

    with torch.no_grad():
        for x, lengths, y in test_loader:
            x = x.to(device)
            y = y.to(device)

            y_pred = model(x, lengths)
            loss = criterion(y_pred, y)
            test_loss += loss.item()

            _, predicted = y_pred.max(1)
            test_correct += (predicted == y).sum().item()
            test_total += y.size(0)

    avg_test_loss = test_loss / len(test_loader)
    test_acc = 100 * test_correct / test_total

    # ==========================================
    # UPDATE BEST TRAIN & TEST RESULTS
    # ==========================================
    if train_acc > best_train_acc:
        best_train_acc = train_acc
        best_train_acc_test_acc = test_acc

    if test_acc > best_test_acc:
        best_test_acc = test_acc
        best_test_acc_train_acc = train_acc
        if epoch > 70: # Asi no guardo en todas las iteraciones iniciales
            torch.save(model.state_dict(), "best_params.pth")
    # ==========================================

    # ======================
    # PRINT SUMMARY
    # ======================
    print(f"Epoch {epoch+1}/{EPOCH} | Train Acc: {train_acc:.2f}% | Test Acc: {test_acc:.2f}%")

# ==========================================
# FINAL RESULTS
# ==========================================
print("\n================ FINAL RESULTS ================")
print(f"Highest Train Acc: {best_train_acc:.2f}% (Test Acc at that time: {best_train_acc_test_acc:.2f}%)")
print(f"Highest Test Acc:  {best_test_acc:.2f}% (Train Acc at that time: {best_test_acc_train_acc:.2f}%)")
print("===============================================\n")
# Out:
# Epoch 1/200 | Train Acc: 4.38% | Test Acc: 4.85%
# Epoch 2/200 | Train Acc: 4.38% | Test Acc: 7.20%
# Epoch 3/200 | Train Acc: 10.00% | Test Acc: 10.64%
# Epoch 4/200 | Train Acc: 14.38% | Test Acc: 10.33%
# Epoch 5/200 | Train Acc: 13.12% | Test Acc: 11.89%
# Epoch 6/200 | Train Acc: 14.38% | Test Acc: 12.83%
# Epoch 7/200 | Train Acc: 18.75% | Test Acc: 14.71%
# Epoch 8/200 | Train Acc: 20.00% | Test Acc: 17.21%
# Epoch 9/200 | Train Acc: 20.00% | Test Acc: 18.15%
# Epoch 10/200 | Train Acc: 16.88% | Test Acc: 18.31%
# Epoch 11/200 | Train Acc: 15.62% | Test Acc: 17.53%
# Epoch 12/200 | Train Acc: 24.38% | Test Acc: 16.74%
# Epoch 13/200 | Train Acc: 18.12% | Test Acc: 20.19%
# Epoch 14/200 | Train Acc: 21.25% | Test Acc: 23.32%
# Epoch 15/200 | Train Acc: 30.00% | Test Acc: 23.63%
# Epoch 16/200 | Train Acc: 41.25% | Test Acc: 27.54%
# Epoch 17/200 | Train Acc: 30.62% | Test Acc: 27.54%
# Epoch 18/200 | Train Acc: 33.12% | Test Acc: 27.54%
# Epoch 19/200 | Train Acc: 35.00% | Test Acc: 30.83%
# Epoch 20/200 | Train Acc: 42.50% | Test Acc: 34.12%
# Epoch 21/200 | Train Acc: 36.88% | Test Acc: 35.05%
# Epoch 22/200 | Train Acc: 40.62% | Test Acc: 28.48%
# Epoch 23/200 | Train Acc: 35.62% | Test Acc: 32.86%
# Epoch 24/200 | Train Acc: 43.75% | Test Acc: 38.34%
# Epoch 25/200 | Train Acc: 36.25% | Test Acc: 35.99%
# Epoch 26/200 | Train Acc: 37.50% | Test Acc: 38.97%
# Epoch 27/200 | Train Acc: 46.25% | Test Acc: 38.97%
# Epoch 28/200 | Train Acc: 46.88% | Test Acc: 37.72%
# Epoch 29/200 | Train Acc: 43.75% | Test Acc: 37.72%
# Epoch 30/200 | Train Acc: 45.62% | Test Acc: 43.04%
# Epoch 31/200 | Train Acc: 53.12% | Test Acc: 42.57%
# Epoch 32/200 | Train Acc: 48.75% | Test Acc: 42.88%
# Epoch 33/200 | Train Acc: 46.88% | Test Acc: 40.06%
# Epoch 34/200 | Train Acc: 50.62% | Test Acc: 46.64%
# Epoch 35/200 | Train Acc: 49.38% | Test Acc: 49.14%
# Epoch 36/200 | Train Acc: 58.75% | Test Acc: 43.82%
# Epoch 37/200 | Train Acc: 50.62% | Test Acc: 44.91%
# Epoch 38/200 | Train Acc: 46.25% | Test Acc: 46.17%
# Epoch 39/200 | Train Acc: 50.62% | Test Acc: 51.49%
# Epoch 40/200 | Train Acc: 50.62% | Test Acc: 53.68%
# Epoch 41/200 | Train Acc: 64.38% | Test Acc: 56.49%
# Epoch 42/200 | Train Acc: 60.00% | Test Acc: 52.43%
# Epoch 43/200 | Train Acc: 56.88% | Test Acc: 52.11%
# Epoch 44/200 | Train Acc: 44.38% | Test Acc: 47.57%
# Epoch 45/200 | Train Acc: 64.38% | Test Acc: 58.22%
# Epoch 46/200 | Train Acc: 61.25% | Test Acc: 52.27%
# Epoch 47/200 | Train Acc: 66.25% | Test Acc: 58.69%
# Epoch 48/200 | Train Acc: 66.88% | Test Acc: 59.47%
# Epoch 49/200 | Train Acc: 61.25% | Test Acc: 60.56%
# Epoch 50/200 | Train Acc: 61.88% | Test Acc: 56.18%
# Epoch 51/200 | Train Acc: 63.75% | Test Acc: 56.34%
# Epoch 52/200 | Train Acc: 70.62% | Test Acc: 59.00%
# Epoch 53/200 | Train Acc: 63.12% | Test Acc: 57.90%
# Epoch 54/200 | Train Acc: 62.50% | Test Acc: 60.25%
# Epoch 55/200 | Train Acc: 52.50% | Test Acc: 47.89%
# Epoch 56/200 | Train Acc: 66.88% | Test Acc: 61.35%
# Epoch 57/200 | Train Acc: 72.50% | Test Acc: 59.62%
# Epoch 58/200 | Train Acc: 55.00% | Test Acc: 60.41%
# Epoch 59/200 | Train Acc: 60.62% | Test Acc: 56.49%
# Epoch 60/200 | Train Acc: 72.50% | Test Acc: 57.12%
# Epoch 61/200 | Train Acc: 67.50% | Test Acc: 62.75%
# Epoch 62/200 | Train Acc: 63.12% | Test Acc: 62.60%
# Epoch 63/200 | Train Acc: 66.25% | Test Acc: 63.38%
# Epoch 64/200 | Train Acc: 65.00% | Test Acc: 63.54%
# Epoch 65/200 | Train Acc: 65.00% | Test Acc: 59.62%
# Epoch 66/200 | Train Acc: 75.00% | Test Acc: 64.01%
# Epoch 67/200 | Train Acc: 74.38% | Test Acc: 65.41%
# Epoch 68/200 | Train Acc: 73.12% | Test Acc: 68.39%
# Epoch 69/200 | Train Acc: 68.75% | Test Acc: 68.08%
# Epoch 70/200 | Train Acc: 75.62% | Test Acc: 66.98%
# Epoch 71/200 | Train Acc: 83.75% | Test Acc: 68.86%
# Epoch 72/200 | Train Acc: 70.62% | Test Acc: 68.86%
# Epoch 73/200 | Train Acc: 81.25% | Test Acc: 69.01%
# Epoch 74/200 | Train Acc: 73.75% | Test Acc: 68.70%
# Epoch 75/200 | Train Acc: 73.75% | Test Acc: 64.16%
# Epoch 76/200 | Train Acc: 72.50% | Test Acc: 69.01%
# Epoch 77/200 | Train Acc: 73.75% | Test Acc: 66.35%
# Epoch 78/200 | Train Acc: 71.88% | Test Acc: 70.58%
# Epoch 79/200 | Train Acc: 54.38% | Test Acc: 50.08%
# Epoch 80/200 | Train Acc: 73.75% | Test Acc: 69.48%
# Epoch 81/200 | Train Acc: 73.12% | Test Acc: 63.54%
# Epoch 82/200 | Train Acc: 80.62% | Test Acc: 72.77%
# Epoch 83/200 | Train Acc: 60.00% | Test Acc: 64.79%
# Epoch 84/200 | Train Acc: 77.50% | Test Acc: 69.95%
# Epoch 85/200 | Train Acc: 69.38% | Test Acc: 66.67%
# Epoch 86/200 | Train Acc: 71.25% | Test Acc: 66.98%
# Epoch 87/200 | Train Acc: 80.62% | Test Acc: 71.83%
# Epoch 88/200 | Train Acc: 76.25% | Test Acc: 71.21%
# Epoch 89/200 | Train Acc: 71.88% | Test Acc: 70.74%
# Epoch 90/200 | Train Acc: 67.50% | Test Acc: 69.01%
# Epoch 91/200 | Train Acc: 76.25% | Test Acc: 73.71%
# Epoch 92/200 | Train Acc: 73.75% | Test Acc: 69.95%
# Epoch 93/200 | Train Acc: 75.00% | Test Acc: 73.08%
# Epoch 94/200 | Train Acc: 66.25% | Test Acc: 63.22%
# Epoch 95/200 | Train Acc: 70.00% | Test Acc: 62.91%
# Epoch 96/200 | Train Acc: 78.75% | Test Acc: 72.14%
# Epoch 97/200 | Train Acc: 73.75% | Test Acc: 75.12%
# Epoch 98/200 | Train Acc: 80.62% | Test Acc: 73.40%
# Epoch 99/200 | Train Acc: 76.25% | Test Acc: 74.18%
# Epoch 100/200 | Train Acc: 76.25% | Test Acc: 73.40%
# Epoch 101/200 | Train Acc: 81.25% | Test Acc: 72.30%
# Epoch 102/200 | Train Acc: 79.38% | Test Acc: 75.43%
# Epoch 103/200 | Train Acc: 81.88% | Test Acc: 73.24%
# Epoch 104/200 | Train Acc: 78.75% | Test Acc: 72.77%
# Epoch 105/200 | Train Acc: 72.50% | Test Acc: 75.43%
# Epoch 106/200 | Train Acc: 76.88% | Test Acc: 74.18%
# Epoch 107/200 | Train Acc: 75.62% | Test Acc: 76.37%
# Epoch 108/200 | Train Acc: 77.50% | Test Acc: 76.21%
# Epoch 109/200 | Train Acc: 78.12% | Test Acc: 74.02%
# Epoch 110/200 | Train Acc: 71.25% | Test Acc: 72.30%
# Epoch 111/200 | Train Acc: 78.12% | Test Acc: 77.62%
# Epoch 112/200 | Train Acc: 68.12% | Test Acc: 70.27%
# Epoch 113/200 | Train Acc: 80.00% | Test Acc: 75.43%
# Epoch 114/200 | Train Acc: 74.38% | Test Acc: 77.93%
# Epoch 115/200 | Train Acc: 82.50% | Test Acc: 75.74%
# Epoch 116/200 | Train Acc: 86.88% | Test Acc: 76.21%
# Epoch 117/200 | Train Acc: 80.62% | Test Acc: 78.87%
# Epoch 118/200 | Train Acc: 82.50% | Test Acc: 77.78%
# Epoch 119/200 | Train Acc: 83.75% | Test Acc: 78.40%
# Epoch 120/200 | Train Acc: 81.88% | Test Acc: 76.84%
# Epoch 121/200 | Train Acc: 81.25% | Test Acc: 78.40%
# Epoch 122/200 | Train Acc: 64.38% | Test Acc: 55.09%
# Epoch 123/200 | Train Acc: 82.50% | Test Acc: 74.33%
# Epoch 124/200 | Train Acc: 85.00% | Test Acc: 77.31%
# Epoch 125/200 | Train Acc: 83.12% | Test Acc: 76.84%
# Epoch 126/200 | Train Acc: 81.25% | Test Acc: 74.96%
# Epoch 127/200 | Train Acc: 86.88% | Test Acc: 77.93%
# Epoch 128/200 | Train Acc: 85.00% | Test Acc: 80.13%
# Epoch 129/200 | Train Acc: 85.00% | Test Acc: 78.72%
# Epoch 130/200 | Train Acc: 77.50% | Test Acc: 76.06%
# Epoch 131/200 | Train Acc: 82.50% | Test Acc: 78.87%
# Epoch 132/200 | Train Acc: 80.62% | Test Acc: 77.15%
# Epoch 133/200 | Train Acc: 70.00% | Test Acc: 73.71%
# Epoch 134/200 | Train Acc: 85.62% | Test Acc: 78.25%
# Epoch 135/200 | Train Acc: 85.62% | Test Acc: 78.72%
# Epoch 136/200 | Train Acc: 83.12% | Test Acc: 81.06%
# Epoch 137/200 | Train Acc: 86.25% | Test Acc: 80.59%
# Epoch 138/200 | Train Acc: 86.25% | Test Acc: 80.44%
# Epoch 139/200 | Train Acc: 85.62% | Test Acc: 80.91%
# Epoch 140/200 | Train Acc: 90.00% | Test Acc: 81.38%
# Epoch 141/200 | Train Acc: 87.50% | Test Acc: 81.53%
# Epoch 142/200 | Train Acc: 86.88% | Test Acc: 83.26%
# Epoch 143/200 | Train Acc: 80.62% | Test Acc: 78.87%
# Epoch 144/200 | Train Acc: 47.50% | Test Acc: 45.70%
# Epoch 145/200 | Train Acc: 78.12% | Test Acc: 76.37%
# Epoch 146/200 | Train Acc: 82.50% | Test Acc: 81.38%
# Epoch 147/200 | Train Acc: 87.50% | Test Acc: 82.16%
# Epoch 148/200 | Train Acc: 85.62% | Test Acc: 81.38%
# Epoch 149/200 | Train Acc: 85.00% | Test Acc: 80.28%
# Epoch 150/200 | Train Acc: 81.25% | Test Acc: 80.44%
# Epoch 151/200 | Train Acc: 88.12% | Test Acc: 82.32%
# Epoch 152/200 | Train Acc: 88.75% | Test Acc: 82.32%
# Epoch 153/200 | Train Acc: 88.75% | Test Acc: 82.47%
# Epoch 154/200 | Train Acc: 93.12% | Test Acc: 83.10%
# Epoch 155/200 | Train Acc: 87.50% | Test Acc: 80.28%
# Epoch 156/200 | Train Acc: 88.12% | Test Acc: 82.94%
# Epoch 157/200 | Train Acc: 91.25% | Test Acc: 83.72%
# Epoch 158/200 | Train Acc: 86.25% | Test Acc: 82.47%
# Epoch 159/200 | Train Acc: 86.88% | Test Acc: 84.04%
# Epoch 160/200 | Train Acc: 90.62% | Test Acc: 85.29%
# Epoch 161/200 | Train Acc: 87.50% | Test Acc: 83.10%
# Epoch 162/200 | Train Acc: 92.50% | Test Acc: 85.92%
# Epoch 163/200 | Train Acc: 89.38% | Test Acc: 84.82%
# Epoch 164/200 | Train Acc: 95.62% | Test Acc: 85.92%
# Epoch 165/200 | Train Acc: 90.00% | Test Acc: 81.69%
# Epoch 166/200 | Train Acc: 88.12% | Test Acc: 82.94%
# Epoch 167/200 | Train Acc: 91.88% | Test Acc: 85.45%
# Epoch 168/200 | Train Acc: 93.12% | Test Acc: 85.29%
# Epoch 169/200 | Train Acc: 90.62% | Test Acc: 83.41%
# Epoch 170/200 | Train Acc: 84.38% | Test Acc: 81.22%
# Epoch 171/200 | Train Acc: 80.00% | Test Acc: 79.34%
# Epoch 172/200 | Train Acc: 91.88% | Test Acc: 85.45%
# Epoch 173/200 | Train Acc: 90.62% | Test Acc: 85.29%
# Epoch 174/200 | Train Acc: 89.38% | Test Acc: 85.92%
# Epoch 175/200 | Train Acc: 93.75% | Test Acc: 86.23%
# Epoch 176/200 | Train Acc: 90.62% | Test Acc: 86.23%
# Epoch 177/200 | Train Acc: 94.38% | Test Acc: 84.82%
# Epoch 178/200 | Train Acc: 92.50% | Test Acc: 87.64%
# Epoch 179/200 | Train Acc: 91.25% | Test Acc: 87.64%
# Epoch 180/200 | Train Acc: 85.62% | Test Acc: 84.98%
# Epoch 181/200 | Train Acc: 86.25% | Test Acc: 84.04%
# Epoch 182/200 | Train Acc: 92.50% | Test Acc: 85.13%
# Epoch 183/200 | Train Acc: 91.88% | Test Acc: 82.63%
# Epoch 184/200 | Train Acc: 81.88% | Test Acc: 80.44%
# Epoch 185/200 | Train Acc: 89.38% | Test Acc: 84.35%
# Epoch 186/200 | Train Acc: 91.25% | Test Acc: 88.89%
# Epoch 187/200 | Train Acc: 91.88% | Test Acc: 86.23%
# Epoch 188/200 | Train Acc: 91.88% | Test Acc: 87.64%
# Epoch 189/200 | Train Acc: 88.75% | Test Acc: 88.42%
# Epoch 190/200 | Train Acc: 91.88% | Test Acc: 88.26%
# Epoch 191/200 | Train Acc: 91.25% | Test Acc: 88.89%
# Epoch 192/200 | Train Acc: 93.12% | Test Acc: 89.98%
# Epoch 193/200 | Train Acc: 93.12% | Test Acc: 89.83%
# Epoch 194/200 | Train Acc: 90.00% | Test Acc: 87.17%
# Epoch 195/200 | Train Acc: 95.62% | Test Acc: 88.89%
# Epoch 196/200 | Train Acc: 95.62% | Test Acc: 89.20%
# Epoch 197/200 | Train Acc: 95.00% | Test Acc: 88.73%
# Epoch 198/200 | Train Acc: 94.38% | Test Acc: 88.26%
# Epoch 199/200 | Train Acc: 95.00% | Test Acc: 90.61%
# Epoch 200/200 | Train Acc: 95.00% | Test Acc: 89.05%
#
# ================ FINAL RESULTS ================
# Highest Train Acc: 95.62% (Test Acc at that time: 85.92%)
# Highest Test Acc:  90.61% (Train Acc at that time: 95.00%)
# ===============================================

# %% [markdown]
# Highest Train Acc: 100.00% (Test Acc at that time: 95.45%)
#
# Highest Test Acc:  98.27% (Train Acc at that time: 100.00%)
#
# # Resultados
# - RNN simple, tanh, 5 capas ocultas y 1 de salida, adam, lr=1e-4, lambda=1e-3: 99.38%, 89.94%
#   -  Alrededor del doble de datos: 95%, 94.19%
#
# Generaliza para el culo en el mundo real, no es capaz de predecir ni una seña. Sospecho porque en los videos estan todos sentados de la misma forma. Lo que quiero hacer es
# - Sacar los landmarks de el torso. Solo tener los landmarks de los brazos y la mano
# - Hacer una primera RNN que se dedique a determinar si es una seña de ambas manos o si es de solo la habil(derecha o izquierda, dataset augmentation para zurdos)
# - Hacer una segunda etapa dedicada a determinar la seña
#   - Una unica RNN con un filtro en su input y reemplazando la mano no-usada con ceros, transfer learning pero quizas le cueste generalizar
#   - 2 RNNs diferentes. Una para ambas manos, otra para la mano habil, quizas generalize mejor pero no hay transfer learning
#
# # Ideas para probar
# - **REVISAR QUE MODELOS Y ARQUITECTURAS QUE HACEN ESTO YA EXISTEN**
# - La idea de PCA para dataset augmentation
#   - Agregar vectores de direccion aleatorios a la muñeca/nudillo y mover el resto del brazo con kinesis
# - Transfer learning usando otro lenguaje de señas similar al argentino pero mas completo
# -   Freezar las conexiones recurrentes? Freezar las primeras capas?
# - Un par de capas ocultas mas
# - Un par de capas ocultas no recurrentes con ReLU
# - Usar una GRU o echo state network para mayor memoria a largo plazo(me parece al pedo una LSTM porque si ya con este nivel de memoria se maneja bien, entonces no creo necesitar tanto control)
# - Encontrar una representacion menos ruidosa para los datos(el z lo infiere mal mediapipe en teoria, y la escala de las manos interpoladas tienen mucho ruido)
# - Quizas reducir los fps a 6 o menos
# - Aumentar el tamaño de los batches
# - Reducir el learning rate a $10^{-4}$ una vez que llegue ~80% porque oscila mucho
#   - Fijarme en un grafico el punto donde empieza a oscilar
#   - No graficar simplemente el train error, graficar la diferencia porcentual entre el train error anterior y este

# %%
# Recargar el mejor modelo
model.load_state_dict(torch.load("best_params.pth", map_location=device))
# Out:
# /tmp/ipykernel_719535/2149482387.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_params.pth", map_location=device))
# <All keys matched successfully>

# %%
# Ahora guardar la softmax de la seña correcta para cada seña en un csv, asi hago analisis despues
labels = []
softmax_score = []

model.eval()
with torch.no_grad():
    for loader in (train_loader, test_loader):
        print("a")
        for x, lengths, y in loader:
            x = x.to(device)
            y = y.to(device)

            y_pred = model(x, lengths)
            _, predicted = y_pred.max(1)
            probs = torch.softmax(y_pred, dim=1)

            for i in range(len(predicted)):
                if int(y[i]) == int(predicted[i]):
                    labels.append(y[i].item())
                    softmax_score.append(probs[i][y[i]].item())
# Out:
# a
# a

# %%
import pandas as pd
df = pd.DataFrame({"label": labels, "softmax_score": softmax_score})
df.to_csv("rnn_scores.csv", index=False)
